# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df1=pd.read_csv("D:\AirPassengers.csv")

# %%
df1.dtypes
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
df1=pd.read_csv("D:\AirPassengers.csv",parse_dates=['Month'],index_col=['Month'])

# %%
df1
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
df1.dtypes
# Out:
# #Passengers    int64
# dtype: object

# %%
df1.plot()
plt.show()

# %%
from pylab import rcParams

# %%
rcParams['figure.figsize']=10,5
df1.plot()
plt.show()

# %%
df1_decom=seasonal_decompose(df1,model='multiplicative')

# %%
df1_decom.plot()
plt.show()

# %%
df2=df1.copy()

# %%
df2['Passengers']=np.log(df2)

# %%
df2.Passengers
# Out:
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791
#                 ...
# 1960-08-01    6.406880
# 1960-09-01    6.230481
# 1960-10-01    6.133398
# 1960-11-01    5.966147
# 1960-12-01    6.068426
# Name: Passengers, Length: 144, dtype: float64

# %%
plt.subplot(2,1,1)
plt.title("Original")
plt.plot(df1)

plt.subplot(2,1,2)
plt.title("Duplicate")
plt.plot(df2)
plt.tight_layout()
