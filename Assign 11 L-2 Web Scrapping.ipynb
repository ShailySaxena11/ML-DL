# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs

# %%
page_info=requests.get("https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_4_0_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_4_0_na_na_na&as-pos=4&as-type=HISTORY&suggestionId=mobiles&requestId=aabcc373-43c9-4f28-a461-238d69fa03c0&as-backfill=on")

# %%
page_info
# Out:
# <Response [200]>

# %%
soup=bs(page_info.content,'html.parser')

# %%
soup.contents
# Out:
# ['html',
# ...

# %%
mobile_info=soup.find_all('div',class_='col col-7-12')

# %%
print(mobile_info)
# Out:
# [<div class="col col-7-12"><div class="_4rR01T">SAMSUNG Galaxy F04 (Opal Green, 64 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBGKY2V7QZ2QVFSGOGYVU_MOBGKY2V7QZ2QVFS_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>22,724 Ratings </span><span class="_13vcmD">&amp;</span><span> 1,167 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">4 GB RAM | 64 GB ROM | Expandable Upto 1 TB</li><li class="rgWa7D">16.51 cm (6.5 inch) HD Display</li><li class="rgWa7D">13MP + 2MP | 5MP Front Camera</li><li class="rgWa7D">5000 mAh Lithium-Ion Battery</li><li class="rgWa7D">Mediatek Helio P35 Processor</li><li class="rgWa7D">1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories</li></ul></div></div>, <div class="col col-7-12"><div class="_4rR01T">POCO C51 (Royal Blue, 64 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRat
# ...

# %%
print(len(mobile_info))
# Out:
# 24

# %%
mobiles=[]
for mobile in mobile_info:
    name=mobile.find('div',class_='_4rR01T')
    name_cont=name.contents[-1].text.split()[0]
    battery=mobile.find_all('li',class_='rgWa7D')
    bat_cont=battery[3].contents[-1].text.split()[0]
    display=mobile.find_all('li',class_='rgWa7D')
    dis_cont=display[1].contents[-1].text.split()[0]
    mobile_dict={'name':name_cont,
                 'battery':bat_cont,
                 'display':dis_cont}
    mobiles.append(mobile_dict)

# %%
mobiles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6100\3740075401.py in <module>
# ----> 1 mobiles
#
# NameError: name 'mobiles' is not defined

# %%
mobile_df=pd.DataFrame(mobiles)
mobile_df
# Out:
#         name battery display
# 0    SAMSUNG    5000   16.51
# 1       POCO    5000   16.56
# 2       OPPO    5000   16.66
# 3       Good    2500    4.57
# 4       POCO    5000   16.56
# 5    Infinix    6000   16.76
# 6    Infinix    6000   16.76
# 7   Cellecor    2750    4.57
# 8    Infinix    6000   16.76
# 9   MOTOROLA    5000   16.51
# 10  MOTOROLA    5000   16.51
# 11  MOTOROLA    5000   16.51
# 12  MOTOROLA    5000   16.64
# 13      vivo    5000   16.71
# 14      vivo    5000   16.71
# 15      vivo    5000   16.71
# 16   Infinix    5000   16.76
# 17      vivo    5000   16.71
# 18      vivo    5000   16.71
# 19      vivo    5000   16.71
# 20      vivo    5000   16.71
# 21      vivo    5000   16.71
# 22   Infinix    5000   16.76
# 23      vivo    5000   16.71

# %%
mobile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     24 non-null     object
#  1   battery  24 non-null     object
#  2   display  24 non-null     object
# dtypes: object(3)
# memory usage: 704.0+ bytes

# %%
mobile_df.head()
# Out:
#       name battery display
# 0  SAMSUNG    5000   16.51
# 1     POCO    5000   16.56
# 2     OPPO    5000   16.66
# 3     Good    2500    4.57
# 4     POCO    5000   16.56

# %%
mobile_df.isna().sum()
# Out:
# name       0
# battery    0
# display    0
# dtype: int64

# %%
mobile_df1=mobile_df.drop_duplicates()

# %%
mobile_df1.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 5     False
# 7     False
# 9     False
# 12    False
# 13    False
# 16    False
# dtype: bool

# %%
mobile_df1
# Out:
#         name battery display
# 0    SAMSUNG    5000   16.51
# 1       POCO    5000   16.56
# 2       OPPO    5000   16.66
# 3       Good    2500    4.57
# 5    Infinix    6000   16.76
# 7   Cellecor    2750    4.57
# 9   MOTOROLA    5000   16.51
# 12  MOTOROLA    5000   16.64
# 13      vivo    5000   16.71
# 16   Infinix    5000   16.76

# %%
mobile_df1.replace({'A15':1},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6100\1235925983.py in <module>
# ----> 1 mobile_df1.replace({'A15':1},inplace=True)
#
# NameError: name 'mobile_df1' is not defined

# %%
mobile_df1['battery']=mobile_df1['battery'].astype(float)
mobile_df1['display']=mobile_df1['display'].astype(float)

# %%
mobile_df1.to_csv('mobile.csv')

# %%
X=mobile_df1.iloc[:,-2:]
y=mobile_df1.iloc[:,0]

# %%
X
# Out:
#     battery  display
# 0    5000.0    16.51
# 1    5000.0    16.56
# 2    5000.0    16.66
# 3    2500.0     4.57
# 5    6000.0    16.76
# 7    2750.0     4.57
# 9    5000.0    16.51
# 12   5000.0    16.64
# 13   5000.0    16.71
# 16   5000.0    16.76

# %%
y
# Out:
# 0      SAMSUNG
# 1         POCO
# 2         OPPO
# 3         Good
# 5      Infinix
# 7     Cellecor
# 9     MOTOROLA
# 12    MOTOROLA
# 13        vivo
# 16     Infinix
# Name: name, dtype: object
